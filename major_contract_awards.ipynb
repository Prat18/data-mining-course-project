# %%
import pandas as pd

contract= pd.read_csv("/media/pratyush/New Volume/desktop/engineering/cse 5th sem/dm project/Major_Contract_Awards.csv")

# %%
contract.head()
# Out:
#                As of Date  Fiscal Year                 Region  \
# 0  09/06/2017 12:00:00 AM         2004                 AFRICA
# 1  09/06/2017 12:00:00 AM         2004                 AFRICA
# 2  09/06/2017 12:00:00 AM         2004                 AFRICA
# 3  09/06/2017 12:00:00 AM         2004                 AFRICA
# 4  09/06/2017 12:00:00 AM         2004  EAST ASIA AND PACIFIC
#
#   Borrower Country Borrower Country Code Project ID  \
# 0             Mali                    ML    P041723
# 1             Mali                    ML    P041723
# 2             Mali                    ML    P041723
# 3             Mali                    ML    P041723
# 4        Indonesia                    ID    P040528
#
#                      Project Name     Procurement Type Procurement Category  \
# 0  Rural Infrastr (FY00) - (PNIR)  Feasibility Studies  CONSULTANT SERVICES
# 1  Rural Infrastr (FY00) - (PNIR)  Feasibility Studies  CONSULTANT SERVICES
# ...

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151623 entries, 0 to 151622
# Data columns (total 20 columns):
# As of Date                            151623 non-null object
# Fiscal Year                           151623 non-null int64
# Region                                151623 non-null object
# Borrower Country                      151623 non-null object
# Borrower Country Code                 151616 non-null object
# Project ID                            151623 non-null object
# Project Name                          151623 non-null object
# Procurement Type                      151623 non-null object
# Procurement Category                  151623 non-null object
# Procurement Method                    151623 non-null object
# Product line                          151623 non-null object
# Major Sector                          151623 non-null object
# WB Contract Number                    151623 non-null int64
# Contract Description                  151620 non-null object
# ...

# %%
contract["Fiscal Year"].value_counts()
# Out:
# 2004    14513
# 2005    14281
# 2012    12907
# 2013    12313
# 2011    12243
# 2010    12023
# 2014    12016
# 2006    11858
# 2015    10169
# 2009    10149
# 2007     9245
# 2008     9192
# 2016     6787
# 2017     3640
# 2018      287
# Name: Fiscal Year, dtype: int64

# %%
contract["Region"].value_counts()
# Out:
# AFRICA                          39926
# EUROPE AND CENTRAL ASIA         30458
# LATIN AMERICA AND CARIBBEAN     30088
# EAST ASIA AND PACIFIC           23617
# SOUTH ASIA                      19253
# MIDDLE EAST AND NORTH AFRICA     8206
# OTHER                              75
# Name: Region, dtype: int64

# %%
contract["Borrower Country"].value_counts()
# Out:
# Vietnam                            8419
# India                              5812
# China                              5324
# Afghanistan                        5006
# Bangladesh                         3895
# Brazil                             3397
# Congo, Democratic Republic of      3270
# Nicaragua                          3231
# Honduras                           2690
# Bosnia and Herzegovina             2671
# Africa                             2368
# Indonesia                          2281
# Nigeria                            2276
# Colombia                           2247
# Mexico                             2211
# Haiti                              2202
# Guatemala                          2146
# Madagascar                         2133
# Kyrgyz Republic                    2073
# Tajikistan                         1918
# Argentina                          1904
# Azerbaijan                         1883
# Russian Federation                 1880
# ...

# %%
contract["Project Name"].value_counts()
# Out:
# COMM DEVT                                   1097
# VN-RURAL ENERGY 2                           1015
# Proj. in Support of Restruc. of Health       775
# DRC-Emerg MS Rehab & Recovery ERL (FY03)     652
# CO Consolidation of Nat. Publ Mgmt Inf.      638
# GT Support Rural Econ.Dev. Program           601
# SIEP                                         539
# BD: Municipal Services                       522
# SV Income Support and Employability          513
# AF: Edu. Qlty. Improvement Program II        499
# NI PFM Modernization TAL                     493
# VIETNAM WATER RESOURCES ASSISTANCE           491
# VN-SYSTEM ENERGY, EQUITIZATION & RENEWAB     487
# BD: HNP Sector Program                       464
# NI (CRL) Roads Rehab & Maintenance IV        455
# HN Trade Facilitatio & Productivity Enha     422
# BI-Pub Works & Employ Creation (FY01)        413
# BD: Primary Education Dev. Program III       404
# Gujarat Emergency Earthquake Reconstruct     403
# ...

# %%
contract["Procurement Type"].value_counts()
# Out:
# Management /Technical Advice                22809
# Project Management                          13255
# Works, Infrastructure                       11566
# Works, Maintenance and Rehabilitation       10665
# Equipment Information Technology             7158
# Training Services                            4846
# Equipment, Electrical                        4600
# Equipment, Transportation                    4497
# Works, Building                              4367
# Institution building                         4095
# Equipment, Medical                           4025
# Miscellaneous                                3933
# Construction Supervision                     3924
# Administrative Services                      3730
# Works, Installation                          3316
# Procurement Technical Assistance             3186
# Equipment, Educational                       3069
# Feasibility Studies                          2931
# Sector Studies                               2770
# ...

# %%
contract["Procurement Category"].value_counts()
# Out:
# CONSULTANT SERVICES        80455
# GOODS                      37171
# CIVIL WORKS                31014
# NON-CONSULTING SERVICES     2145
# Not assigned                 838
# Name: Procurement Category, dtype: int64

# %%
contract["Procurement Method"].value_counts()
# Out:
# International Competitive Bidding           30949
# Individual Consultant                       27684
# National Competitive Bidding                26629
# Single Source Selection                     20056
# Quality And Cost-Based Selection            18740
# Selection Based On Consultant's Qualific     9098
# Direct Contracting                           6253
# Shopping                                     4956
# Quality Based Selection                      2231
# Least Cost Selection                         1557
# RFB                                          1065
# Selection Under a Fixed Budget                853
# Limited International Bidding                 706
# Service Delivery Contracts                    376
# CDS                                           308
# RFQ                                           132
# UN                                             24
# RFP                                             6
# Name: Procurement Method, dtype: int64

# %%
contract["Major Sector"].value_counts()
# Out:
# Public Administration                          29338
# Water, Sanitation and Waste Management         19599
# (Historic)Health and other social services     18936
# Agriculture, Fishing and Forestry              18122
# Transportation                                 18079
# Education                                      15720
# Energy and Extractives                         13813
# Industry, Trade and Services                    4759
# Social Protection                               4096
# Financial Sector                                3969
# Information and Communications Technologies     2592
# Health                                          2419
# X                                                141
# Not assigned                                      33
# X-                                                 7
# Name: Major Sector, dtype: int64

# %%
contract["As of Date"].value_counts()
# Out:
# 09/06/2017 12:00:00 AM    151623
# Name: As of Date, dtype: int64

# %%
contract["WB Contract Number"].value_counts()
# Out:
# 1278126    20
# 1248278    15
# 1251509    12
# 1520627    12
# 1520614    11
# 1299738    11
# 1250249    10
# 1245003    10
# 1254249    10
# 1235271    10
# 1244915    10
# 1244912    10
# 1248016    10
# 1238879    10
# 1243139    10
# 1258071    10
# 1237378    10
# 1244664    10
# 1256375    10
# 1520625    10
# 1236662    10
# 1234895    10
# 1259752    10
# 1235139     9
# 1520619     9
# 1275366     9
# 1279599     8
# 1244196     8
# 1244683     8
# 1270923     8
#            ..
# 1245747     1
# 1249841     1
# 1303087     1
# 1305134     1
# 1313234     1
# 1311187     1
# 1323477     1
# 1319383     1
# 1327579     1
# 1506181     1
# 1501991     1
# 1547303     1
# 1505934     1
# 1243660     1
# 1501710     1
# 1237519     1
# 1284640     1
# 1282593     1
# 1280546     1
# 1540643     1
# 1292836     1
# 1290789     1
# 1288742     1
# 1286695     1
# 1301032     1
# 1298985     1
# 1296938     1
# 1294891     1
# 1307181     1
# 1312447     1
# ...

# %%
contract["Contract Description"].value_counts()
# Out:
# Procurement Specialist                                          317
# MIGRATIONS SOCIAL ASSESSMENT AND QUESTIONNAIRES                 215
# Project Coordinator                                             158
# PROCUREMENT SPECIALIST                                          146
# Financial Management Specialist                                 138
# MEDICAL EQUIPMENT                                               126
# PROJECT COORDINATOR                                             122
# PLANTATION EN PLEIN, ENTRETIEN ET PROTECTION DES PARCELLES D    104
# Printing, binding and supplying of primary level textbooks f     99
# CONTINUATION OF FACILITATION WORK STARTED IN COMMUNITIES IN      97
# Procurement Officer                                              96
# FNGO FOR PHASE III                                               88
# Monitoring and Evaluation Specialist                             82
# Audit Services                                                   81
# ...

# %%
contract["Contract Signing Date"]. value_counts()
# Out:
# 02/16/2005 12:00:00 AM    263
# 01/04/2010 12:00:00 AM    208
# 08/29/2003 12:00:00 AM    204
# 07/01/2011 12:00:00 AM    192
# 04/01/2011 12:00:00 AM    190
# 06/01/2012 12:00:00 AM    190
# 03/15/2007 12:00:00 AM    187
# 12/31/2012 12:00:00 AM    184
# 12/31/2013 12:00:00 AM    172
# 12/31/2014 12:00:00 AM    171
# 07/01/2009 12:00:00 AM    170
# 04/01/2014 12:00:00 AM    169
# 08/01/2012 12:00:00 AM    168
# 01/02/2013 12:00:00 AM    167
# 07/15/2003 12:00:00 AM    166
# 01/01/2013 12:00:00 AM    158
# 07/01/2013 12:00:00 AM    154
# 04/01/2004 12:00:00 AM    150
# 07/01/2015 12:00:00 AM    149
# 01/02/2006 12:00:00 AM    149
# 08/01/2013 12:00:00 AM    148
# 01/08/2013 12:00:00 AM    141
# 07/01/2012 12:00:00 AM    140
# 12/23/2014 12:00:00 AM    140
# 01/03/2005 12:00:00 AM    138
# 04/30/2013 12:00:00 AM    138
# 12/23/2004 12:00:00 AM    138
# 06/01/2015 12:00:00 AM    136
# 07/01/2014 12:00:00 AM    136
# 12/30/2011 12:00:00 AM    134
#                          ...
# ...

# %%
contract["Supplier"].value_counts()
# Out:
# UNITED NATIONS OFFICE PROJECT SERVICES (UNOPS)                  269
# UNITED NATIONS CHILDREN'S FUND (UNICEF)                         208
# SOFRECO                                                         112
# ERNST & YOUNG                                                    94
# IMTA                                                             89
# FOOD AND AGRICULTURE ORGANIZATION OF UNITED NATIONS (FAO)        86
# STUDI INTERNATIONAL                                              82
# DELOITTE & TOUCHE                                                81
# KPMG                                                             78
# INTER-AGENCY PROCUREMENT SERVICES OFFICE (IAPSO)                 71
# PRICEWATERHOUSECOOPERS                                           70
# AGETIER-MALI                                                     68
# UNITED NATIONS DEVELOPMENT PROGRAMME (UNDP)                      66
# SINOHYDRO CORPORATION LIMITED                                    65
# ...

# %%
contract["Supplier Country"].value_counts()
# Out:
# Vietnam                                 7312
# India                                   6761
# China                                   6323
# Afghanistan                             4231
# Brazil                                  3464
# Nicaragua                               3134
# Bangladesh                              3082
# United States                           2969
# France                                  2956
# United Kingdom                          2757
# Bosnia and Herzegovina                  2416
# Honduras                                2353
# Colombia                                2300
# Indonesia                               2185
# Mexico                                  2178
# Congo, Democratic Republic of           2177
# Guatemala                               2104
# Russian Federation                      2029
# Haiti                                   2013
# Argentina                               1964
# Nigeria                                 1961
# ...

# %%
contract["Product line"].value_counts()
# Out:
# IBRD/IDA                              130006
# Recipient Executed Activities          12422
# Global Environment Project              5121
# Institutional Development Fund          1770
# Special Financing                       1328
# Carbon Offset                            480
# GEF Medium Sized Program                 149
# IFAD Funded Project                       85
# Montreal Protocol                         82
# JSA/PRSP and JSA/I-PRSP                   59
# Guarantees                                57
# GEFSEC Recipent Executed                  28
# Partnership                               17
# Technical Assistance (Non-lending)        12
# Debt Reduction Facility                    5
# Rainforest                                 2
# Name: Product line, dtype: int64

# %%
cont = contract.drop("As of Date", axis=1)

# %%
con = cont.drop("Borrower Country Code", axis=1)

# %%
co = con.drop("Supplier Country Code",axis=1)

# %%
co.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151623 entries, 0 to 151622
# Data columns (total 17 columns):
# Fiscal Year                           151623 non-null int64
# Region                                151623 non-null object
# Borrower Country                      151623 non-null object
# Project ID                            151623 non-null object
# Project Name                          151623 non-null object
# Procurement Type                      151623 non-null object
# Procurement Category                  151623 non-null object
# Procurement Method                    151623 non-null object
# Product line                          151623 non-null object
# Major Sector                          151623 non-null object
# WB Contract Number                    151623 non-null int64
# Contract Description                  151620 non-null object
# Contract Signing Date                 151610 non-null object
# Supplier                              151622 non-null object
# ...

# %%
contract = co

# %%
contract
# Out:
#         Fiscal Year                       Region        Borrower Country  \
# 0              2004                       AFRICA                    Mali
# 1              2004                       AFRICA                    Mali
# 2              2004                       AFRICA                    Mali
# 3              2004                       AFRICA                    Mali
# 4              2004        EAST ASIA AND PACIFIC               Indonesia
# 5              2004        EAST ASIA AND PACIFIC               Indonesia
# 6              2004        EAST ASIA AND PACIFIC             Timor-Leste
# 7              2004        EAST ASIA AND PACIFIC             Timor-Leste
# 8              2004                   SOUTH ASIA              Bangladesh
# 9              2004                   SOUTH ASIA              Bangladesh
# 10             2004                   SOUTH ASIA                  Bhutan
# 11             2004                   SOUTH ASIA                   India
# ...

# %%
contract['Total Contract Amount (USD)'] = contract['Total Contract Amount (USD)'].str.rstrip('$')

# %%
contract.head()
# Out:
#    Fiscal Year                 Region Borrower Country Project ID  \
# 0         2004                 AFRICA             Mali    P041723
# 1         2004                 AFRICA             Mali    P041723
# 2         2004                 AFRICA             Mali    P041723
# 3         2004                 AFRICA             Mali    P041723
# 4         2004  EAST ASIA AND PACIFIC        Indonesia    P040528
#
#                      Project Name     Procurement Type Procurement Category  \
# 0  Rural Infrastr (FY00) - (PNIR)  Feasibility Studies  CONSULTANT SERVICES
# 1  Rural Infrastr (FY00) - (PNIR)  Feasibility Studies  CONSULTANT SERVICES
# 2  Rural Infrastr (FY00) - (PNIR)  Feasibility Studies  CONSULTANT SERVICES
# 3  Rural Infrastr (FY00) - (PNIR)  Feasibility Studies  CONSULTANT SERVICES
# 4           ID-W. JAVA ENVMT MGMT  Policy and Strategy  CONSULTANT SERVICES
#
#                  Procurement Method Product line  \
# 0           Single Source Selection     IBRD/IDA
# ...

# %%
import numpy as np
def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
np.random.seed(42)

# %%
train_set, test_set = split_train_test(contract, 0.2)
print(len(train_set), "train +", len(test_set), "test")
# Out:
# 121299 train + 30324 test

# %%
test_set.head()
# Out:
#         Fiscal Year                       Region    Borrower Country  \
# 50965          2008      EUROPE AND CENTRAL ASIA  Russian Federation
# 111909         2013  LATIN AMERICA AND CARIBBEAN               Haiti
# 4143           2004  LATIN AMERICA AND CARIBBEAN           Argentina
# 86455          2011      EUROPE AND CENTRAL ASIA  Russian Federation
# 127468         2014      EUROPE AND CENTRAL ASIA     Kyrgyz Republic
#
#        Project ID                             Project Name  \
# 50965     P072960                             CUSTOMS DEVT
# 111909    P124134  HT Education for All Project - Phase II
# 4143      P052590                   AR NAT HWY REHAB&MAINT
# 86455     P072960                             CUSTOMS DEVT
# 127468    P131322             Reports to Convention: UNCCD
#
#                         Procurement Type Procurement Category  \
# 50965   Equipment Information Technology                GOODS
# 111909               Awareness Campaigns  CONSULTANT SERVICES
# ...

# %%
train_set.head()
# Out:
#         Fiscal Year                   Region  \
# 108783         2013  EUROPE AND CENTRAL ASIA
# 62401          2009  EUROPE AND CENTRAL ASIA
# 125553         2014                   AFRICA
# 17327          2005  EUROPE AND CENTRAL ASIA
# 114109         2013  EUROPE AND CENTRAL ASIA
#
#                               Borrower Country Project ID  \
# 108783  Macedonia, former Yugoslav Republic of    P083126
# 62401                                   Kosovo    P102165
# 125553                                 Nigeria    P106172
# 17327                                  Moldova    P044840
# 114109                                  Serbia    P094212
#
#                                Project Name              Procurement Type  \
# 108783              REG & REAL ESTATE (CRL)    Hardware/Software Services
# 62401                        AVIAN FLU - XK               Health Services
# 125553   NG-Electricity and Gas Improvement                Audit Services
# ...
